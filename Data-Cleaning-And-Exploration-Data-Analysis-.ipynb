# %% [markdown]
# # Packages and Data Importation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gt = pd.read_csv("C:/Users/user/Documents/My Project/globalterrorismdb_0718dist.csv", encoding = "latin", low_memory = False )

# %% [markdown]
# # Data Accessing

# %%
# Printing the first five rows
gt.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# Printing the last five rows
gt.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %%
# To display the number of rows and columns in our Data Set 
gt.shape
# Out:
# (181691, 135)

# %%
# To display random 10 records in oue Data Set (record's number is depended on the inserted value in the parenthesis)
gt.sample(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 163385  201606070001   2016       6     7        NaN         0        NaN
# 135110  201407170012   2014       7    17        NaN         0        NaN
# 7170    197812170036   1978      12    17        NaN         0        NaN
# 29288   198610020008   1986      10     2        NaN         0        NaN
# 95368   201002150015   2010       2    15        NaN         0        NaN
# 175992  201706160038   2017       6    16        NaN         0        NaN
# 107721  201205110034   2012       5    11        NaN         0        NaN
# 80041   200602270015   2006       2    27        NaN         0        NaN
# 180836  201711270040   2017      11    27        NaN         0        NaN
# 28917   198608130018   1986       8    13        NaN         0        NaN
#
#         country country_txt  region  ...  \
# 163385      209      Turkey      10  ...
# 135110      153    Pakistan       6  ...
# 7170         78      Greece       8  ...
# 29288       159        Peru       3  ...
# 95368        95        Iraq      10  ...
# 175992      200       Syria      10  ...
# 107721      200       Syria      10  ...
# 80041        95        Iraq      10  ...
# 180836       92       India       6  ...
# 28917        43       Chile       3  ...
#
#                                                  addnotes  \
# 163385  Casualty numbers for this incident conflict ac...
# 135110  Casualty numbers for this attack conflict acro...
# 7170                                                  NaN
# 29288                                                 NaN
# 95368                                                 NaN
# 175992  Casualty numbers conflict across sources. Foll...
# 107721                                                NaN
# 80041                                                 NaN
# 180836                                                NaN
# 28917                                                 NaN
#
#                                                    scite1  \
# 163385  "Istanbul bombing: Turkey police arrest four s...
# 135110  "Twin blasts kills seven, injured three in Han...
# 7170                                                  NaN
# 29288                                                 NaN
# 95368   National Counterterrorism Center, "One Person ...
# 175992  "1st LD: Suicide bombing rocks mosque in Syria...
# 107721  "UN observers pelted with stones near Damascus...
# 80041   "Sunni Mosque Bombed as Iraqi Tanks Deploy in ...
# 180836  "Seven Maoists arrested in Narayanpur," The Hi...
# 28917                                                 NaN
#
#                                                    scite2  \
# 163385  "Death toll in Istanbul car bomb attack rises ...
# 135110  "Roadside blast in Hangu kills six, injures th...
# 7170                                                  NaN
# 29288                                                 NaN
# 95368   Hamid Ahmed, "Police: Bomb in Northern Iraq Ki...
# 175992  "Iraq: Abdullah Al-Muhaysisi Blames ISIL for F...
# 107721  "4 army men killed as protest continued over w...
# 80041   "3 People Killed in Northern Iraq, 4 in Baghda...
# 180836                                                NaN
# 28917                                                 NaN
#
#                                                    scite3  \
# 163385  "Kurdish militant group warns foreigners to st...
# 135110  "12 killed in Pakistan," Tunis Afrique Presse ...
# 7170                                                  NaN
# 29288                                                 NaN
# 95368   Qatar News Agency, "Bomb hits Election Campaig...
# 175992  "Dead And Wounded In Motorbike Bomb In Idlib
# ....
# 107721                                                NaN
# 80041   Four Killed, 13 Wounded in Mortar Attack Nort...
# 180836                                                NaN
# 28917                                                 NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 163385  START Primary Collection        0         1        0       1
# 135110  START Primary Collection       -9        -9        0      -9
# 7170                        PGIS       -9        -9        0      -9
# 29288                       PGIS        0         0        0       0
# 95368                       ISVG       -9        -9        0      -9
# 175992  START Primary Collection        0         1        0       1
# 107721  START Primary Collection       -9        -9        0      -9
# 80041                      CETIS       -9        -9        0      -9
# 180836  START Primary Collection        0         0        0       0
# 28917                       PGIS       -9        -9        0      -9
#
#                            related
# 163385                         NaN
# 135110  201407170011, 201407170012
# 7170                           NaN
# 29288                          NaN
# 95368                          NaN
# 175992                         NaN
# 107721                         NaN
# 80041                          NaN
# 180836                         NaN
# 28917                          NaN
#
# [10 rows x 135 columns]

# %%
# To display columns/fields name of our Data Set
gt.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# To check for duplicates records in our Data Set
gt.duplicated().sum()
# Out:
# 0

# %%
# show the columns with less than 50% missing values
missing_values_in_number=gt.isnull().sum()
missing_values_in_percentage =  (gt.isnull().sum() /gt.shape[0]) * 100    
missing_values_in_percentage = round(missing_values_in_percentage, 2)

missing_value=pd.concat([missing_values_in_number,missing_values_in_percentage ],axis=1, keys= ["missing_values_in_number",
                                                                                  "missing_values_in_percentage" ])

missing_value.query("missing_values_in_percentage >0 and missing_values_in_percentage <50",)
# Out:
#                   missing_values_in_number  missing_values_in_percentage
# provstate                              421                          0.23
# city                                   434                          0.24
# latitude                              4556                          2.51
# longitude                             4557                          2.51
# summary                              66129                         36.40
# targsubtype1                         10373                          5.71
# targsubtype1_txt                     10373                          5.71
# corp1                                42550                         23.42
# target1                                636                          0.35
# natlty1                               1559                          0.86
# natlty1_txt                           1559                          0.86
# guncertain1                            380                          0.21
# nperps                               71115                         39.14
# nperpcap                             69489                         38.25
# claimed                              66120                         36.39
# weapsubtype1                         20768                         11.43
# weapsubtype1_txt                     20768                         11.43
# weapdetail                           67670                         37.24
# nkill                                10313                          5.68
# nkillus                              64446                         35.47
# nkillter                             66958                         36.85
# nwound                               16311                          8.98
# nwoundus                             64702                         35.61
# nwoundte                             69143                         38.06
# ishostkid                              178                          0.10
# scite1                               66191                         36.43

# %%
# columns with more than 50% missing values
missing_value.query("missing_values_in_percentage >=50",)
# Out:
#                  missing_values_in_number  missing_values_in_percentage
# approxdate                         172452                         94.91
# resolution                         179471                         98.78
# location                           126196                         69.46
# alternative                        152680                         84.03
# alternative_txt                    152680                         84.03
# ...                                   ...                           ...
# nreleased                          171291                         94.28
# addnotes                           153402                         84.43
# scite2                             104758                         57.66
# scite3                             138175                         76.05
# related                            156653                         86.22
#
# [77 rows x 2 columns]

# %%
gt.sample(15)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 64406   199701120007   1997       1    12        NaN         0        NaN
# 128350  201403050078   2014       3     5        NaN         0        NaN
# 158089  201601250019   2016       1    25        NaN         0        NaN
# 137073  201408270008   2014       8    27        NaN         1        NaN
# 32903   198712100006   1987      12    10        NaN         0        NaN
# 102716  201108140010   2011       8    14        NaN         0        NaN
# 21233   198403070006   1984       3     7        NaN         0        NaN
# 106671  201203300008   2012       3    30        NaN         0        NaN
# 25846   198507300007   1985       7    30        NaN         0        NaN
# 134843  201407130005   2014       7    13        NaN         0        NaN
# 71290   200010260003   2000      10    26        NaN         0        NaN
# 54429   199212090002   1992      12     9        NaN         0        NaN
# 142120  201412290033   2014      12    29        NaN         0        NaN
# 144968  201502260027   2015       2    26        NaN         0        NaN
# 141709  201412180047   2014      12    18        NaN         0        NaN
#
#         country    country_txt  region  ... addnotes  \
# 64406        69         France       8  ...      NaN
# 128350        4    Afghanistan       6  ...      NaN
# 158089       92          India       6  ...      NaN
# 137073      113          Libya      10  ...      NaN
# 32903       145      Nicaragua       2  ...      NaN
# 102716       92          India       6  ...      NaN
# 21233        59        Ecuador       3  ...      NaN
# 106671        4    Afghanistan       6  ...      NaN
# 25846       186      Sri Lanka       6  ...      NaN
# 134843      182        Somalia      11  ...      NaN
# 71290       209         Turkey      10  ...      NaN
# 54429        19     Bangladesh       6  ...      NaN
# 142120      158       Paraguay       3  ...      NaN
# 144968      160    Philippines       5  ...      NaN
# 141709      217  United States       1  ...      NaN
#
#                                                    scite1  \
# 64406                                                 NaN
# 128350  "Bomb defused near Ahmadzai rally venue," Pajh...
# 158089  "Seven cops killed, six injured in Maoist blas...
# 137073  "Solidarity fund manager in Obari freed after ...
# 32903                                                 NaN
# 102716  South Asia Terrorism Portal, "Maoists Kill Rul...
# 21233                                                 NaN
# 106671  "Attacks on Afghan police kill 10: officials,"...
# 25846                                                 NaN
# 134843  "SOCAFRICA: Al-Shabaab (AS) Incident Tracker: ...
# 71290   "Disposal team defuses bomb thrown at prison,"...
# 54429                                                 NaN
# 142120  "The EPP attacks and threats," Paraguay.com, D...
# 144968  "NPA   rebels   burn backhoe owned by Camarine...
# 141709  "North Carolina teen charged in ISIS-inspired ...
#
#                                                    scite2  \
# 64406                                                 NaN
# 128350                                                NaN
# 158089  "'Reds' torch mobile tower in Palamu," Times o...
# 137073  "Libya: Motives Behind Abduction of Jarmah Sol...
# 32903                                                 NaN
# 102716  Times of India, "Cops, Reds Battle it Out on I...
# 21233                                                 NaN
# 106671  "Afghan policeman kills 9 colleagues; joins Ta...
# 25846                                                 NaN
# 134843                                                NaN
# 71290                                                 NaN
# 54429                                                 NaN
# 142120  "Balean truck in Yby Yau," Paraguay.com, Decem...
# 144968                                                NaN
# 141709  "Prosecutors: Islamic State Inspired N. Caroli...
#
#                                                    scite3  \
# 64406                                                 NaN
# 128350                                                NaN
# 158089  "Maoists set mobile tower on fire in Palamu," ...
# 137073  "SOCAFRICA: Libya Incident Tracker: 23  29 Au...
# 32903                                                 NaN
# 102716  United News of India, "Bullets Exchanged Betwe...
# 21233                                                 NaN
# 106671  "Afghan police: 9 officers killed," Associated...
# 25846                                                 NaN
# 134843                                                NaN
# 71290                                                 NaN
# 54429                                                 NaN
# 142120                                                NaN
# 144968                                                NaN
# 141709  "North Carolina teen, accused of supporting IS...
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 64406                       PGIS        1         0        0       1
# 128350  START Primary Collection       -9        -9        0      -9
# 158089  START Primary Collection        0         0        0       0
# 137073  START Primary Collection       -9        -9        0      -9
# 32903                       PGIS        0         0        0       0
# 102716                      ISVG        0         0        0       0
# 21233                       PGIS       -9        -9        0      -9
# 106671  START Primary Collection        0         0        0       0
# 25846                       PGIS        0         1        1       1
# 134843  START Primary Collection        0         0        0       0
# 71290            UMD Schmid 2012       -9        -9        0      -9
# 54429                       PGIS       -9        -9        0      -9
# 142120  START Primary Collection        0         0        0       0
# 144968  START Primary Collection        0         0        0       0
# 141709  START Primary Collection       -9        -9        0      -9
#
#                                                   related
# 64406   199701120007, 199701120006, 199701120008, 1997...
# 128350                                                NaN
# 158089                                                NaN
# 137073                                                NaN
# 32903                                                 NaN
# 102716                                                NaN
# 21233                                                 NaN
# 106671                                                NaN
# 25846                                                 NaN
# 134843                                                NaN
# 71290                                                 NaN
# 54429                                                 NaN
# 142120                                                NaN
# 144968                                                NaN
# 141709                                                NaN
#
# [15 rows x 135 columns]

# %% [markdown]
# # Data Cleaning

# %%
# drop all columns with more than 50% missing values
x=missing_value.query("missing_values_in_percentage >=50",)
r=x.index.to_list()
gt.drop(columns=r, inplace=True)

# %%
# drop all the columns with little weight 
gt.drop(columns=["latitude","longitude", "targsubtype1", "natlty1", "guncertain1", "nperps", "nperpcap", "claimed", 
             "weapsubtype1", "nkill", "nkillus", "nkillter", "nwound", "nwoundte", "nwoundus", "ishostkid"], inplace=True)

# %%
# drop the missing value the subset of the following columns
gt.dropna(subset=["provstate", "city", "summary", "doubtterr", "multiple", "targsubtype1_txt", "corp1",
        "target1", "weapdetail", "scite1", "weapsubtype1_txt",  "natlty1_txt", "specificity"], inplace=True, axis=0)

# %%
gt.shape
# Out:
# (39880, 42)

# %%
clean_gt = gt.copy()
df=clean_gt.drop(columns=["INT_LOG", "INT_IDEO", "INT_MISC", "INT_ANY", 'crit1', 'crit2', 'crit3', 
                       'specificity', 'vicinity'])

# %%
# 
total_crime_per_year=df.iyear.value_counts().to_frame("Crime Rate per Year").nlargest(10,
                                                                             "Crime Rate per Year").sort_index()


total_crime_success_per_year=df.query("success==1")["iyear"].value_counts().to_frame().nlargest(10, "iyear").sort_index()


s=pd.merge(total_crime_per_year, total_crime_success_per_year, left_index=True,     right_index=True,)

# %%
fig, ax = plt.subplots(figsize=(12,8), facecolor="grey")

s.plot(kind="bar", y=["Crime Rate per Year", "iyear"] , ax=ax, cmap='Dark2')
plt.title("hh", loc='center')
plt.ylabel("Total Count", color="blue", fontsize=30)
plt.xlabel("Year")
ax.tick_params(axis="x", labelrotation=0)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city', 'summary',
#        'doubtterr', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1_txt', 'gname', 'individual', 'weaptype1',
#        'weaptype1_txt', 'weapsubtype1_txt', 'weapdetail', 'property', 'scite1',
#        'dbsource'],
#       dtype='object')

# %%
df.gname
# Out:
# 5                                 Black Nationalists
# 8                                    New Year's Gang
# 9                                    New Year's Gang
# 11                               Left-Wing Militants
# 13                               Left-Wing Militants
#                              ...
# 181680                                    Al-Shabaab
# 181681    Bangsamoro Islamic Freedom Movement (BIFM)
# 181684                      Zeliangrong United Front
# 181687                             Muslim extremists
# 181689                                       Unknown
# Name: gname, Length: 39880, dtype: object

# %%
z=df[df["country_txt"]=="Nigeria"]["weaptype1_txt"].value_counts().head()
z.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(12,8), facecolor="Grey")
df[df["country_txt"]=="Nigeria"]["gname"].value_counts().head().plot(kind="bar")
plt.tick_params(labelrotation=25)

# %%
fig, ax = plt.subplots(figsize=(12,8), facecolor="grey")
d=df[   df["country_txt"] =="Nigeria"]["city"].value_counts().head(10).to_frame()
ax.pie(x=d["city"],wedgeprops={'width': 0.2}, labels=d.index, autopct="%.2f%%")
plt.show()

# %%
d
# Out:
#                  city
# Maiduguri         132
# Kano               35
# Unknown            27
# Logo district      24
# Port Harcourt      15
# Kukawa district    13
# Gombe              12
# Konduga            11
# Damaturu           11
# Lagos              10

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city', 'summary',
#        'doubtterr', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1_txt', 'gname', 'individual', 'weaptype1',
#        'weaptype1_txt', 'weapsubtype1_txt', 'weapdetail', 'property', 'scite1',
#        'dbsource'],
#       dtype='object')

# %%
# Types of attacks launched by the terrorist
df["attacktype1_txt"].value_counts().to_frame()
# Out:
#                                      attacktype1_txt
# Bombing/Explosion                              26182
# Armed Assault                                   7846
# Assassination                                   2708
# Facility/Infrastructure Attack                  1838
# Hostage Taking (Kidnapping)                      899
# Unarmed Assault                                  173
# Hostage Taking (Barricade Incident)              159
# Hijacking                                         68
# Unknown                                            7

# %%
df.attacktype1_txt.value_counts().to_frame()
# Out:
#                                      attacktype1_txt
# Bombing/Explosion                              26182
# Armed Assault                                   7846
# Assassination                                   2708
# Facility/Infrastructure Attack                  1838
# Hostage Taking (Kidnapping)                      899
# Unarmed Assault                                  173
# Hostage Taking (Barricade Incident)              159
# Hijacking                                         68
# Unknown                                            7

# %%
df["country_txt"].value_counts().head(10).to_frame()
# Out:
#                country_txt
# Iraq                  7644
# Pakistan              4453
# Afghanistan           3880
# India                 2938
# Philippines           1857
# Thailand              1547
# Somalia               1383
# Syria                 1061
# United States         1041
# Yemen                  993

# %%
df.weaptype1_txt.value_counts().to_frame()
# Out:
#             weaptype1_txt
# Explosives          29176
# Firearms             7657
# Incendiary           2096
# Melee                 844
# Chemical              107

# %%
attacktype1_txt

# %%
   df[ df["country_txt"] == "United States"][["eventid", "iyear", "imonth"]]
# Out:
#              eventid  iyear  imonth
# 5       197001010002   1970       1
# 8       197001020003   1970       1
# 9       197001030001   1970       1
# 11      197001060001   1970       1
# 13      197001090001   1970       1
# ...              ...    ...     ...
# 180304  201711070054   2017      11
# 181141  201712070037   2017      12
# 181219  201712110001   2017      12
# 181478  201712220022   2017      12
# 181479  201712220023   2017      12
#
# [1041 rows x 3 columns]
